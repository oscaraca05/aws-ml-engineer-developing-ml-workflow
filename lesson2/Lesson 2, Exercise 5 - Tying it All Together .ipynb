# %% [markdown]
# # UDACITY SageMaker Essentials: Tying it all Together
#
# ## Using XGBoost in SageMaker
#
#
# To tie everything together, we'll be using Amazon's SageMaker service to construct a random tree model to predict the sentiment of a movie review. This is also a sentiment analysis problem but we won't be using BlazingText. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
# Once you this notebook is opened in SageMaker Studio, select "Python3(Data Science)" kernel with "ml.g4dn.xlarge" instance.
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data --no-same-owner
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2022-09-09 23:13:58--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  29.4MB/s    in 2.7s
#
# 2022-09-09 23:14:01 (29.4 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100], train_y[100]
# Out:
# ('What can I say about this film other than "don\'t see it". I waited and waited and WAITED for someting (or anything) to happen and it just didn\'t come. Watch amazingly as two people walk around while setting the record for most filler screen time in a single movie. What are they doing? Are they solving a mystery? Are they gathering clues? Possibly, it\'s just hard to tell. At the end of the movie, after a lot of radio signals are decoded (illegibly on some sort of PET monitor) and this guy gives some lectures, the plot is finally revealed and tossed aside as quickly as possible. Some aliens want to get back to their home world utopia and are so happy there that they want to blow up the earth (I guess they don\'t like sharing the wealth). My guess is they finished filming and saw their 35 minute work or art (garbage!) and decided that they\'d let the editing crew turn it into an 88 minute feature film. Watch at your own peril, it\'s not even funny because it\'s so bad, it\'s just bad.',
#  0)

# %%
len(train_X), len(train_y), len(test_X), len(test_y)
# Out:
# (25000, 25000, 25000, 25000)

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X[:2000], test_X[:2000], train_y[:2000], test_y[:2000])
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl

# %%
len(train_X), len(train_y), len(test_X), len(test_y)
# Out:
# (2000, 2000, 2000, 2000)

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Read features from cache file: bow_features.pkl

# %%
train_X.shape, test_X.shape
# Out:
# ((2000, 5000), (2000, 5000))

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### (TODO) Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

# TODO: Split the train_X and train_y arrays into the DataFrames val_X, train_X and val_y, train_y. 
# Make sure that val_X and val_y contain 10000 entires while train_X and train_y contain the remaining 15000 entries.
val_X = train_X[:800,:]
val_y = train_y[:800]

train_X = train_X[800:,:]
train_y = train_y[800:]

# %%
train_X.shape, len(train_y), val_X.shape, len(val_y)
# Out:
# ((1200, 5000), 1200, (800, 5000), 800)

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = 'data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
df_train = pd.concat([pd.DataFrame(train_y, columns=['label']), pd.DataFrame(train_X, columns=['f'+str(x) for x in range(1,5001)])], axis=1)
df_val = pd.concat([pd.DataFrame(val_y, columns=['label']), pd.DataFrame(val_X, columns=['f'+str(x) for x in range(1,5001)])], axis=1)
df_train.shape, df_val.shape
# Out:
# ((1200, 5001), (800, 5001))

# %%
# Then, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# TODO: Save the training and validation data to train.csv and validation.csv in the data_dir directory.
# Make sure that the files you create include the ground truth and are in the correct format.
df_train.to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)
df_val.to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

test_X = train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### (TODO) Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# The method `upload_data()`, a member of the object representing our current SageMaker session, may be of use to you. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker session.upload_data](https://sagemaker.readthedocs.io/en/latest/session.html#sagemaker.session.Session.upload_data)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

# TODO: Upload the test.csv, train.csv and validation.csv files which are contained in data_dir to S3 using sess.upload_data().
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating the XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. To begin with, we need to do some setup. At this point it is worth discussing what a model is in SageMaker. It is easiest to think of a model of comprising three different objects in the SageMaker ecosystem, which interact with one another.
#
# - Model Artifacts
# - Training Code (Container)
# - Inference Code (Container)
#
# The Model Artifacts are what you might think of as the actual model itself. For example, if you were building a neural network, the model artifacts would be the weights of the various layers. In our case, for an XGBoost model, the artifacts are the actual trees that are created during training.
#
# The other two objects, the training code and the inference code are then used the manipulate the training artifacts. More precisely, the training code uses the training data that is provided and creates the model artifacts, while the inference code uses the model artifacts to make predictions on new data.
#
# The way that SageMaker runs the training and inference code is by making use of Docker containers. For now, think of a container as being a way of packaging code up so that dependencies aren't an issue.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker import image_uris
container = image_uris.retrieve('xgboost', session.boto_region_name, 'latest')

# %%
session.list_s3_files()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-f613053b32c8> in <module>
# ----> 1 session.list_s3_files()
#
# TypeError: list_s3_files() missing 2 required positional arguments: 'bucket' and 'key_prefix'

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(image_uri=container, 
                              role=role, 
                              instance_count=1,
                              instance_type='ml.m4.xlarge',
                              output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                              sagemaker_session=session)


# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.
xgb.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.7,
    verbosity=1,
    objective='binary:logistic',
    num_round=500)

# %% [markdown]
# ### Fit the XGBoost model
#
# Now that our model has been set up we simply need to attach the training and validation datasets and then ask SageMaker to set up the computation.

# %%
s3_input_train = sagemaker.TrainingInput(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.TrainingInput(s3_data=val_location, content_type='csv')

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2022-09-12 21:28:43 Starting - Starting the training job...ProfilerReport-1663018123: InProgress
# ...
# 2022-09-12 21:29:30 Starting - Preparing the instances for training.........
# 2022-09-12 21:31:10 Downloading - Downloading input data......
# 2022-09-12 21:32:10 Training - Downloading the training image....Arguments: train
# [2022-09-12:21:32:50:INFO] Running standalone xgboost training.
# [2022-09-12:21:32:50:INFO] File size need to be processed in the node: 19.08mb. Available memory size in the node: 8769.98mb
# [2022-09-12:21:32:50:INFO] Determined delimiter of CSV input is ','
# [21:32:50] S3DistributionType set as FullyReplicated
# [21:32:51] 1200x5000 matrix with 6000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2022-09-12:21:32:51:INFO] Determined delimiter of CSV input is ','
# [21:32:51] S3DistributionType set as FullyReplicated
# [21:32:51] 800x5000 matrix with 4000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [21:32:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [0]#011train-error:0.306667#011validation-error:0.31875
# [21:32:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [1]#011train-error:0.2775#011validation-error:0.2875
# [21:32:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [2]#011train-error:0.273333#011validation-error:0.2725
# [21:32:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [3]#011train-error:0.2525#011validation-error:0.2775
# [21:32:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [4]#011train-error:0.2425#011validation-error:0.27875
# [21:32:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [5]#011train-error:0.236667#011validation-error:0.2875
# [21:32:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [6]#011train-error:0.228333#011validation-error:0.2725
# [21:32:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [7]#011train-error:0.224167#011validation-error:0.28
# [21:32:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [8]#011train-error:0.209167#011validation-error:0.28625
# [21:32:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [9]#011train-error:0.210833#011validation-error:0.26875
# [21:32:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [10]#011train-error:0.206667#011validation-error:0.2725
# [21:32:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [11]#011train-error:0.199167#011validation-error:0.26875
# [21:32:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [12]#011train-error:0.1925#011validation-error:0.2725
# [21:32:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [13]#011train-error:0.190833#011validation-error:0.2625
# [21:32:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [14]#011train-error:0.180833#011validation-error:0.2575
# [21:32:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [15]#011train-error:0.180833#011validation-error:0.25125
# [21:32:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [16]#011train-error:0.185#011validation-error:0.26
# [21:32:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [17]#011train-error:0.18#011validation-error:0.2525
# [21:32:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [18]#011train-error:0.175833#011validation-error:0.25
# [21:32:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [19]#011train-error:0.173333#011validation-error:0.2525
# [21:32:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [20]#011train-error:0.166667#011validation-error:0.245
# [21:32:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [21]#011train-error:0.166667#011validation-error:0.25
# [21:32:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [22]#011train-error:0.160833#011validation-error:0.24125
# [21:32:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [23]#011train-error:0.155#011validation-error:0.24625
# [21:32:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [24]#011train-error:0.156667#011validation-error:0.2475
# [21:32:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [25]#011train-error:0.145#011validation-error:0.25
# [21:32:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [26]#011train-error:0.1425#011validation-error:0.2475
# [21:32:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [27]#011train-error:0.14#011validation-error:0.25125
# [21:32:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [28]#011train-error:0.145833#011validation-error:0.25625
# [21:32:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [29]#011train-error:0.133333#011validation-error:0.245
# [21:32:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [30]#011train-error:0.135#011validation-error:0.2375
# [21:32:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [31]#011train-error:0.135#011validation-error:0.2375
# [21:32:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [32]#011train-error:0.131667#011validation-error:0.23375
# [21:32:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [33]#011train-error:0.134167#011validation-error:0.2375
# [21:32:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=3
# [34]#011train-error:0.139167#011validation-error:0.23125
# [21:32:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [35]#011train-error:0.128333#011validation-error:0.2275
# [21:32:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [36]#011train-error:0.125#011validation-error:0.225
# [21:32:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [37]#011train-error:0.125833#011validation-error:0.2275
# [21:32:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [38]#011train-error:0.1275#011validation-error:0.23
# [21:32:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [39]#011train-error:0.125833#011validation-error:0.22875
# [21:32:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [40]#011train-error:0.118333#011validation-error:0.22375
# [21:32:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [41]#011train-error:0.1175#011validation-error:0.2175
# [21:32:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [42]#011train-error:0.115833#011validation-error:0.22125
# [21:32:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [43]#011train-error:0.119167#011validation-error:0.22125
# [21:32:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 10 pruned nodes, max_depth=2
# [44]#011train-error:0.115#011validation-error:0.22625
# [21:32:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [45]#011train-error:0.110833#011validation-error:0.2225
# [21:32:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [46]#011train-error:0.113333#011validation-error:0.2225
# [21:33:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [47]#011train-error:0.1125#011validation-error:0.22625
# [21:33:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [48]#011train-error:0.1075#011validation-error:0.21875
# [21:33:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [49]#011train-error:0.1075#011validation-error:0.22
# [21:33:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [50]#011train-error:0.106667#011validation-error:0.2225
# [21:33:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [51]#011train-error:0.105#011validation-error:0.22
# [21:33:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 8 pruned nodes, max_depth=2
# [52]#011train-error:0.106667#011validation-error:0.21875
# [21:33:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 8 pruned nodes, max_depth=1
# [53]#011train-error:0.108333#011validation-error:0.2175
# [21:33:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [54]#011train-error:0.109167#011validation-error:0.21875
# [21:33:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 14 pruned nodes, max_depth=2
# [55]#011train-error:0.104167#011validation-error:0.22
# [21:33:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [56]#011train-error:0.103333#011validation-error:0.21625
# [21:33:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [57]#011train-error:0.101667#011validation-error:0.20875
# [21:33:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [58]#011train-error:0.1#011validation-error:0.20625
# [21:33:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 16 pruned nodes, max_depth=1
# [59]#011train-error:0.100833#011validation-error:0.21
# [21:33:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [60]#011train-error:0.1#011validation-error:0.205
# [21:33:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [61]#011train-error:0.1#011validation-error:0.20375
# [21:33:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [62]#011train-error:0.100833#011validation-error:0.20625
# [21:33:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 8 pruned nodes, max_depth=2
# [63]#011train-error:0.096667#011validation-error:0.2075
# [21:33:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=4
# [64]#011train-error:0.095#011validation-error:0.2075
#
# 2022-09-12 21:33:11 Training - Training image download completed. Training in progress.[21:33:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [65]#011train-error:0.086667#011validation-error:0.21125
# [21:33:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 14 pruned nodes, max_depth=2
# [66]#011train-error:0.090833#011validation-error:0.2125
# [21:33:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [67]#011train-error:0.09#011validation-error:0.2125
# [21:33:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=3
# [68]#011train-error:0.09#011validation-error:0.2125
# [21:33:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 14 pruned nodes, max_depth=2
# [69]#011train-error:0.086667#011validation-error:0.215
# [21:33:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 8 pruned nodes, max_depth=2
# [70]#011train-error:0.086667#011validation-error:0.2125
# [21:33:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 10 pruned nodes, max_depth=2
# [71]#011train-error:0.084167#011validation-error:0.21125
# [21:33:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [72]#011train-error:0.085833#011validation-error:0.21625
# [21:33:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [73]#011train-error:0.086667#011validation-error:0.21625
# [21:33:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [74]#011train-error:0.086667#011validation-error:0.21625
# [21:33:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [75]#011train-error:0.085#011validation-error:0.21625
# [21:33:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [76]#011train-error:0.085#011validation-error:0.215
# [21:33:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [77]#011train-error:0.085#011validation-error:0.21625
# [21:33:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [78]#011train-error:0.083333#011validation-error:0.21375
# [21:33:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [79]#011train-error:0.081667#011validation-error:0.21875
# [21:33:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [80]#011train-error:0.0825#011validation-error:0.21875
# [21:33:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [81]#011train-error:0.083333#011validation-error:0.21875
# [21:33:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [82]#011train-error:0.081667#011validation-error:0.21875
# [21:33:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [83]#011train-error:0.081667#011validation-error:0.21875
# [21:33:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [84]#011train-error:0.0825#011validation-error:0.21875
# [21:33:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [85]#011train-error:0.083333#011validation-error:0.21875
# [21:33:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [86]#011train-error:0.083333#011validation-error:0.21875
# [21:33:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [87]#011train-error:0.083333#011validation-error:0.21875
# [21:33:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [88]#011train-error:0.083333#011validation-error:0.21875
# [21:33:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [89]#011train-error:0.083333#011validation-error:0.21875
# [21:33:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 10 pruned nodes, max_depth=2
# [90]#011train-error:0.081667#011validation-error:0.21875
# [21:33:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 10 pruned nodes, max_depth=2
# [91]#011train-error:0.084167#011validation-error:0.2175
# [21:33:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [92]#011train-error:0.080833#011validation-error:0.21625
# [21:33:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 8 pruned nodes, max_depth=1
# [93]#011train-error:0.080833#011validation-error:0.215
# [21:33:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [94]#011train-error:0.080833#011validation-error:0.21625
# [21:33:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [95]#011train-error:0.080833#011validation-error:0.215
# [21:33:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [96]#011train-error:0.080833#011validation-error:0.21375
# [21:33:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [97]#011train-error:0.075833#011validation-error:0.2125
# [21:33:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 6 pruned nodes, max_depth=2
# [98]#011train-error:0.0775#011validation-error:0.21125
# [21:33:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [99]#011train-error:0.0775#011validation-error:0.20875
# [21:33:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [100]#011train-error:0.0775#011validation-error:0.20875
# [21:33:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [101]#011train-error:0.076667#011validation-error:0.20875
# [21:33:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [102]#011train-error:0.075833#011validation-error:0.20875
# [21:33:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [103]#011train-error:0.075833#011validation-error:0.20875
# [21:33:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [104]#011train-error:0.075833#011validation-error:0.20875
# [21:33:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [105]#011train-error:0.076667#011validation-error:0.20625
# [21:33:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [106]#011train-error:0.0775#011validation-error:0.20625
# [21:33:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [107]#011train-error:0.0775#011validation-error:0.20625
# [21:33:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [108]#011train-error:0.0775#011validation-error:0.2075
# [21:33:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [109]#011train-error:0.0775#011validation-error:0.20625
# [21:33:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [110]#011train-error:0.0775#011validation-error:0.20875
# [21:33:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [111]#011train-error:0.078333#011validation-error:0.20875
# [21:33:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [112]#011train-error:0.078333#011validation-error:0.20875
# [21:33:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [113]#011train-error:0.078333#011validation-error:0.2075
# [21:33:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [114]#011train-error:0.0775#011validation-error:0.2075
# [21:33:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [115]#011train-error:0.0775#011validation-error:0.2075
# [21:33:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [116]#011train-error:0.0775#011validation-error:0.2075
# [21:33:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [117]#011train-error:0.0775#011validation-error:0.2075
# [21:33:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [118]#011train-error:0.080833#011validation-error:0.20875
# [21:33:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 16 pruned nodes, max_depth=1
# [119]#011train-error:0.08#011validation-error:0.20625
# [21:33:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [120]#011train-error:0.08#011validation-error:0.20625
# [21:33:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [121]#011train-error:0.08#011validation-error:0.20625
# [21:33:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [122]#011train-error:0.080833#011validation-error:0.20625
# [21:33:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [123]#011train-error:0.080833#011validation-error:0.20625
# [21:33:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [124]#011train-error:0.08#011validation-error:0.2075
# [21:33:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [125]#011train-error:0.08#011validation-error:0.2075
# [21:33:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [126]#011train-error:0.08#011validation-error:0.2075
# [21:33:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 12 pruned nodes, max_depth=2
# [127]#011train-error:0.0775#011validation-error:0.20375
# [21:33:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [128]#011train-error:0.0775#011validation-error:0.205
# [21:33:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [129]#011train-error:0.0775#011validation-error:0.20375
# [21:33:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [130]#011train-error:0.078333#011validation-error:0.205
# [21:33:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [131]#011train-error:0.079167#011validation-error:0.205
# [21:33:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [132]#011train-error:0.0775#011validation-error:0.20375
# [21:33:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [133]#011train-error:0.0775#011validation-error:0.205
# [21:33:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [134]#011train-error:0.079167#011validation-error:0.205
# [21:33:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [135]#011train-error:0.079167#011validation-error:0.205
# [21:33:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [136]#011train-error:0.078333#011validation-error:0.205
# [21:33:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [137]#011train-error:0.0775#011validation-error:0.20375
# [21:33:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [138]#011train-error:0.0775#011validation-error:0.205
# [21:33:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [139]#011train-error:0.075833#011validation-error:0.2075
# [21:33:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [140]#011train-error:0.075833#011validation-error:0.20875
# [21:33:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [141]#011train-error:0.075833#011validation-error:0.20875
# [21:33:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [142]#011train-error:0.075833#011validation-error:0.20875
# [21:33:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [143]#011train-error:0.075833#011validation-error:0.20875
# [21:33:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [144]#011train-error:0.075833#011validation-error:0.20875
# [21:33:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [145]#011train-error:0.075#011validation-error:0.21
# [21:33:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 8 pruned nodes, max_depth=1
# [146]#011train-error:0.075833#011validation-error:0.20625
# [21:33:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 8 pruned nodes, max_depth=1
# [147]#011train-error:0.073333#011validation-error:0.2075
# [21:33:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [148]#011train-error:0.073333#011validation-error:0.20625
# [21:33:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [149]#011train-error:0.073333#011validation-error:0.20375
# [21:33:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [150]#011train-error:0.073333#011validation-error:0.20375
# [21:33:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [151]#011train-error:0.073333#011validation-error:0.20375
# [21:33:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [152]#011train-error:0.073333#011validation-error:0.205
# [21:33:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [153]#011train-error:0.073333#011validation-error:0.2075
# [21:33:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [154]#011train-error:0.073333#011validation-error:0.20375
# [21:33:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [155]#011train-error:0.073333#011validation-error:0.20375
# [21:33:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [156]#011train-error:0.073333#011validation-error:0.20375
# [21:33:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [157]#011train-error:0.075#011validation-error:0.2075
# [21:33:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [158]#011train-error:0.075#011validation-error:0.20875
# [21:33:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [159]#011train-error:0.075#011validation-error:0.20875
# [21:33:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [160]#011train-error:0.075#011validation-error:0.2075
# [21:33:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [161]#011train-error:0.075#011validation-error:0.21125
# [21:33:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [162]#011train-error:0.0725#011validation-error:0.21125
# [21:33:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [163]#011train-error:0.0725#011validation-error:0.21125
# [21:33:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [164]#011train-error:0.0725#011validation-error:0.21
# [21:33:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [165]#011train-error:0.0725#011validation-error:0.21125
# [21:33:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [166]#011train-error:0.0725#011validation-error:0.21
# [21:33:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [167]#011train-error:0.0725#011validation-error:0.21
# [21:33:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [168]#011train-error:0.0725#011validation-error:0.21125
# [21:33:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [169]#011train-error:0.0725#011validation-error:0.21
# [21:33:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [170]#011train-error:0.07#011validation-error:0.21
# [21:33:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [171]#011train-error:0.07#011validation-error:0.20875
# [21:33:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [172]#011train-error:0.07#011validation-error:0.21125
# [21:33:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [173]#011train-error:0.07#011validation-error:0.21
# [21:33:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [174]#011train-error:0.07#011validation-error:0.20875
# [21:33:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [175]#011train-error:0.07#011validation-error:0.20875
# [21:33:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [176]#011train-error:0.070833#011validation-error:0.21
# [21:33:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [177]#011train-error:0.071667#011validation-error:0.20625
# [21:33:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [178]#011train-error:0.0725#011validation-error:0.21
# [21:33:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [179]#011train-error:0.0725#011validation-error:0.21
# [21:33:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [180]#011train-error:0.0725#011validation-error:0.21
# [21:33:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [181]#011train-error:0.0725#011validation-error:0.21
# [21:33:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [182]#011train-error:0.071667#011validation-error:0.20625
# [21:33:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [183]#011train-error:0.071667#011validation-error:0.20625
# [21:33:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [184]#011train-error:0.0725#011validation-error:0.21
# [21:33:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [185]#011train-error:0.0725#011validation-error:0.21
# [21:33:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [186]#011train-error:0.071667#011validation-error:0.21
# [21:33:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [187]#011train-error:0.071667#011validation-error:0.2125
# [21:33:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [188]#011train-error:0.070833#011validation-error:0.20625
# [21:33:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 22 pruned nodes, max_depth=0
# [189]#011train-error:0.070833#011validation-error:0.20625
# [21:33:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [190]#011train-error:0.070833#011validation-error:0.20625
# [21:33:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [191]#011train-error:0.070833#011validation-error:0.20625
# [21:33:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 14 pruned nodes, max_depth=1
# [192]#011train-error:0.07#011validation-error:0.21
# [21:33:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [193]#011train-error:0.068333#011validation-error:0.21125
# [21:33:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [194]#011train-error:0.069167#011validation-error:0.21
# [21:33:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [195]#011train-error:0.07#011validation-error:0.21
# [21:33:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [196]#011train-error:0.07#011validation-error:0.20625
# [21:33:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [197]#011train-error:0.070833#011validation-error:0.21
# [21:33:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [198]#011train-error:0.069167#011validation-error:0.20625
# [21:33:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [199]#011train-error:0.068333#011validation-error:0.21375
# [21:33:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [200]#011train-error:0.068333#011validation-error:0.21375
# [21:33:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [201]#011train-error:0.068333#011validation-error:0.215
# [21:33:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [202]#011train-error:0.068333#011validation-error:0.215
# [21:33:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [203]#011train-error:0.068333#011validation-error:0.215
# [21:33:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [204]#011train-error:0.068333#011validation-error:0.215
# [21:33:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [205]#011train-error:0.068333#011validation-error:0.215
# [21:33:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [206]#011train-error:0.069167#011validation-error:0.21125
# [21:33:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [207]#011train-error:0.07#011validation-error:0.21125
# [21:33:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [208]#011train-error:0.07#011validation-error:0.21
# [21:33:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [209]#011train-error:0.07#011validation-error:0.2075
# [21:33:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [210]#011train-error:0.07#011validation-error:0.21
# [21:33:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [211]#011train-error:0.069167#011validation-error:0.2075
# [21:33:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 8 pruned nodes, max_depth=1
# [212]#011train-error:0.069167#011validation-error:0.21125
# [21:33:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [213]#011train-error:0.07#011validation-error:0.21125
# [21:33:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [214]#011train-error:0.069167#011validation-error:0.21
# [21:33:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [215]#011train-error:0.069167#011validation-error:0.2075
# [21:33:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [216]#011train-error:0.069167#011validation-error:0.21125
# [21:33:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [217]#011train-error:0.0675#011validation-error:0.21375
# [21:33:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [218]#011train-error:0.0675#011validation-error:0.21375
# [21:33:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [219]#011train-error:0.0675#011validation-error:0.21375
# [21:33:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [220]#011train-error:0.069167#011validation-error:0.21
# [21:33:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [221]#011train-error:0.069167#011validation-error:0.2125
# [21:33:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [222]#011train-error:0.068333#011validation-error:0.21375
# [21:33:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [223]#011train-error:0.068333#011validation-error:0.2125
# [21:33:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [224]#011train-error:0.069167#011validation-error:0.21125
# [21:33:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [225]#011train-error:0.069167#011validation-error:0.21125
# [21:33:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 12 pruned nodes, max_depth=1
# [226]#011train-error:0.0675#011validation-error:0.215
# [21:33:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [227]#011train-error:0.068333#011validation-error:0.21375
# [21:33:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [228]#011train-error:0.068333#011validation-error:0.21375
# [21:33:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [229]#011train-error:0.069167#011validation-error:0.215
# [21:33:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=3
# [230]#011train-error:0.069167#011validation-error:0.21625
# [21:33:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [231]#011train-error:0.068333#011validation-error:0.21625
# [21:33:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [232]#011train-error:0.069167#011validation-error:0.21625
# [21:33:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [233]#011train-error:0.069167#011validation-error:0.21625
# [21:33:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [234]#011train-error:0.069167#011validation-error:0.21625
# [21:33:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [235]#011train-error:0.068333#011validation-error:0.22
# [21:33:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [236]#011train-error:0.069167#011validation-error:0.21625
# [21:33:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [237]#011train-error:0.069167#011validation-error:0.21625
# [21:33:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [238]#011train-error:0.069167#011validation-error:0.21625
# [21:33:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [239]#011train-error:0.068333#011validation-error:0.21375
# [21:33:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [240]#011train-error:0.068333#011validation-error:0.21375
# [21:33:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [241]#011train-error:0.068333#011validation-error:0.21375
# [21:33:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [242]#011train-error:0.068333#011validation-error:0.215
# [21:33:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [243]#011train-error:0.066667#011validation-error:0.2125
# [21:33:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [244]#011train-error:0.0675#011validation-error:0.2125
# [21:33:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [245]#011train-error:0.0675#011validation-error:0.21375
# [21:33:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [246]#011train-error:0.0675#011validation-error:0.2125
# [21:33:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [247]#011train-error:0.0675#011validation-error:0.2125
# [21:33:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 10 pruned nodes, max_depth=2
# [248]#011train-error:0.065#011validation-error:0.21625
# [21:33:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 6 pruned nodes, max_depth=2
# [249]#011train-error:0.064167#011validation-error:0.21375
# [21:33:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [250]#011train-error:0.063333#011validation-error:0.21375
# [21:33:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [251]#011train-error:0.063333#011validation-error:0.21375
# [21:33:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [252]#011train-error:0.063333#011validation-error:0.21375
# [21:33:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [253]#011train-error:0.064167#011validation-error:0.21375
# [21:33:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [254]#011train-error:0.0625#011validation-error:0.21625
# [21:33:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [255]#011train-error:0.064167#011validation-error:0.21625
# [21:33:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [256]#011train-error:0.064167#011validation-error:0.21625
# [21:33:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [257]#011train-error:0.063333#011validation-error:0.21625
# [21:33:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [258]#011train-error:0.064167#011validation-error:0.21625
# [21:33:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [259]#011train-error:0.064167#011validation-error:0.21625
# [21:33:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [260]#011train-error:0.064167#011validation-error:0.21625
# [21:33:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [261]#011train-error:0.063333#011validation-error:0.215
# [21:33:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [262]#011train-error:0.064167#011validation-error:0.21375
# [21:33:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [263]#011train-error:0.064167#011validation-error:0.21625
# [21:33:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [264]#011train-error:0.064167#011validation-error:0.21625
# [21:33:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [265]#011train-error:0.064167#011validation-error:0.21625
# [21:33:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [266]#011train-error:0.063333#011validation-error:0.215
# [21:33:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [267]#011train-error:0.063333#011validation-error:0.215
# [21:33:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [268]#011train-error:0.063333#011validation-error:0.21375
# [21:33:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [269]#011train-error:0.064167#011validation-error:0.21625
# [21:33:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [270]#011train-error:0.063333#011validation-error:0.21625
# [21:33:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [271]#011train-error:0.063333#011validation-error:0.21625
# [21:33:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [272]#011train-error:0.064167#011validation-error:0.21625
# [21:33:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [273]#011train-error:0.064167#011validation-error:0.21625
# [21:33:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [274]#011train-error:0.0625#011validation-error:0.21625
# [21:33:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [275]#011train-error:0.064167#011validation-error:0.215
# [21:33:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [276]#011train-error:0.064167#011validation-error:0.21375
# [21:33:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [277]#011train-error:0.063333#011validation-error:0.21375
# [21:33:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [278]#011train-error:0.063333#011validation-error:0.21375
# [21:33:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# ...
# [406]#011train-error:0.060833#011validation-error:0.1975
# [21:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [407]#011train-error:0.060833#011validation-error:0.1975
# [21:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [408]#011train-error:0.060833#011validation-error:0.1975
# [21:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [409]#011train-error:0.061667#011validation-error:0.19875
# [21:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [410]#011train-error:0.061667#011validation-error:0.19875
# [21:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [411]#011train-error:0.0625#011validation-error:0.2
# [21:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [412]#011train-error:0.061667#011validation-error:0.2025
# [21:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [413]#011train-error:0.061667#011validation-error:0.2025
# [21:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [414]#011train-error:0.061667#011validation-error:0.2025
# [21:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [415]#011train-error:0.061667#011validation-error:0.2025
# [21:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [416]#011train-error:0.061667#011validation-error:0.2025
# [21:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [417]#011train-error:0.061667#011validation-error:0.2025
# [21:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [418]#011train-error:0.061667#011validation-error:0.2025
# [21:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [419]#011train-error:0.061667#011validation-error:0.20375
# [21:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [420]#011train-error:0.061667#011validation-error:0.20375
# [21:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [421]#011train-error:0.061667#011validation-error:0.2025
# [21:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [422]#011train-error:0.061667#011validation-error:0.2025
# [21:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [423]#011train-error:0.061667#011validation-error:0.19875
# [21:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [424]#011train-error:0.060833#011validation-error:0.1975
# [21:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [425]#011train-error:0.060833#011validation-error:0.1975
# [21:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [426]#011train-error:0.060833#011validation-error:0.1975
# [21:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [427]#011train-error:0.061667#011validation-error:0.1975
# [21:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [428]#011train-error:0.061667#011validation-error:0.2025
# [21:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [429]#011train-error:0.061667#011validation-error:0.2025
# [21:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [430]#011train-error:0.061667#011validation-error:0.2025
# [21:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [431]#011train-error:0.0625#011validation-error:0.20375
# [21:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [432]#011train-error:0.063333#011validation-error:0.20125
# [21:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [433]#011train-error:0.061667#011validation-error:0.2025
# [21:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [434]#011train-error:0.061667#011validation-error:0.2025
# [21:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [435]#011train-error:0.0625#011validation-error:0.20375
# [21:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [436]#011train-error:0.0625#011validation-error:0.2
# [21:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [437]#011train-error:0.061667#011validation-error:0.2025
# [21:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 22 pruned nodes, max_depth=0
# [438]#011train-error:0.0625#011validation-error:0.2
# [21:34:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [439]#011train-error:0.061667#011validation-error:0.2025
# [21:34:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [440]#011train-error:0.061667#011validation-error:0.2025
# [21:34:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [441]#011train-error:0.061667#011validation-error:0.2025
# [21:34:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [442]#011train-error:0.0625#011validation-error:0.2025
# [21:34:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [443]#011train-error:0.061667#011validation-error:0.2025
# [21:34:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [444]#011train-error:0.063333#011validation-error:0.20125
# [21:34:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [445]#011train-error:0.063333#011validation-error:0.2
# [21:34:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [446]#011train-error:0.061667#011validation-error:0.2
# [21:34:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [447]#011train-error:0.061667#011validation-error:0.2
# [21:34:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [448]#011train-error:0.060833#011validation-error:0.20125
# [21:34:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [449]#011train-error:0.061667#011validation-error:0.20125
# [21:34:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [450]#011train-error:0.061667#011validation-error:0.20375
# [21:34:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [451]#011train-error:0.061667#011validation-error:0.2025
# [21:34:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [452]#011train-error:0.060833#011validation-error:0.20375
# [21:34:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 14 pruned nodes, max_depth=2
# [453]#011train-error:0.064167#011validation-error:0.20625
# [21:34:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [454]#011train-error:0.064167#011validation-error:0.20625
# [21:34:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [455]#011train-error:0.064167#011validation-error:0.20625
# [21:34:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [456]#011train-error:0.064167#011validation-error:0.205
# [21:34:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [457]#011train-error:0.064167#011validation-error:0.205
# [21:34:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [458]#011train-error:0.064167#011validation-error:0.205
# [21:34:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [459]#011train-error:0.064167#011validation-error:0.20625
# [21:34:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [460]#011train-error:0.064167#011validation-error:0.20625
# [21:34:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [461]#011train-error:0.064167#011validation-error:0.205
# [21:34:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [462]#011train-error:0.064167#011validation-error:0.205
# [21:34:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [463]#011train-error:0.064167#011validation-error:0.205
# [21:34:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [464]#011train-error:0.064167#011validation-error:0.205
# [21:34:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [465]#011train-error:0.064167#011validation-error:0.20625
# [21:34:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [466]#011train-error:0.064167#011validation-error:0.20625
# [21:34:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [467]#011train-error:0.064167#011validation-error:0.205
# [21:34:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [468]#011train-error:0.065#011validation-error:0.20375
# [21:34:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [469]#011train-error:0.065833#011validation-error:0.20375
# [21:34:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [470]#011train-error:0.064167#011validation-error:0.2075
# [21:34:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [471]#011train-error:0.065833#011validation-error:0.20375
# [21:34:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [472]#011train-error:0.063333#011validation-error:0.20625
# [21:34:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [473]#011train-error:0.063333#011validation-error:0.20625
# [21:34:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [474]#011train-error:0.063333#011validation-error:0.20625
# [21:34:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [475]#011train-error:0.063333#011validation-error:0.20625
# [21:34:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [476]#011train-error:0.061667#011validation-error:0.21
# [21:34:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [477]#011train-error:0.061667#011validation-error:0.20875
# [21:34:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [478]#011train-error:0.060833#011validation-error:0.20875
# [21:34:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [479]#011train-error:0.061667#011validation-error:0.21
# [21:34:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [480]#011train-error:0.061667#011validation-error:0.20875
# [21:34:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [481]#011train-error:0.060833#011validation-error:0.20875
# [21:34:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [482]#011train-error:0.061667#011validation-error:0.20875
# [21:34:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [483]#011train-error:0.060833#011validation-error:0.20875
# [21:34:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [484]#011train-error:0.060833#011validation-error:0.20875
# [21:34:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [485]#011train-error:0.06#011validation-error:0.20875
# [21:34:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [486]#011train-error:0.061667#011validation-error:0.20875
# [21:34:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [487]#011train-error:0.061667#011validation-error:0.20875
# [21:34:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [488]#011train-error:0.061667#011validation-error:0.20875
# [21:34:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [489]#011train-error:0.060833#011validation-error:0.20875
# [21:34:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [490]#011train-error:0.061667#011validation-error:0.21
# [21:34:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [491]#011train-error:0.061667#011validation-error:0.21
# [21:34:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [492]#011train-error:0.060833#011validation-error:0.20875
# [21:34:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [493]#011train-error:0.060833#011validation-error:0.20875
# [21:34:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [494]#011train-error:0.060833#011validation-error:0.20875
# [21:34:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [495]#011train-error:0.06#011validation-error:0.21
# [21:34:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [496]#011train-error:0.06#011validation-error:0.21
# [21:34:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [497]#011train-error:0.061667#011validation-error:0.20875
# [21:34:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [498]#011train-error:0.061667#011validation-error:0.21
# [21:34:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [499]#011train-error:0.061667#011validation-error:0.20875
#
# 2022-09-12 21:34:44 Uploading - Uploading generated training model
# 2022-09-12 21:34:44 Completed - Training job completed
# Training seconds: 223
# Billable seconds: 223

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've fit our XGBoost model, it's time to see how well it performs. To do this we will use SageMakers Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# To perform a Batch Transformation we need to first create a transformer objects from our trained estimator object.

# %%
# TODO: Create a transformer object from the trained model. 
# Using an instance count of 1 and an instance type of ml.m4.xlarge should be more than enough.
xgb_transformer = xgb.transformer(instance_count=1, instance_type='ml.m4.xlarge')

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(
    data=test_location, 
    data_type='S3Prefix',
    content_type='text/csv', 
    split_type='Line'
)

xgb_transformer.wait()
# Out:
# .....................................Arguments: serve
# [2022-09-12 21:46:34 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-09-12 21:46:34 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-09-12 21:46:34 +0000] [1] [INFO] Using worker: gevent
# [2022-09-12 21:46:34 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-09-12 21:46:34 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-09-12 21:46:34 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-09-12 21:46:35 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 21
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 23
# Arguments: serve
# [2022-09-12 21:46:34 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-09-12 21:46:34 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-09-12 21:46:34 +0000] [1] [INFO] Using worker: gevent
# [2022-09-12 21:46:34 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-09-12 21:46:34 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-09-12 21:46:34 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-09-12 21:46:35 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 21
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 24
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# 2022-09-12T21:46:38.916:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
#
# Arguments: serve
# [2022-09-12 21:46:34 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-09-12 21:46:34 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-09-12 21:46:34 +0000] [1] [INFO] Using worker: gevent
# [2022-09-12 21:46:34 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-09-12 21:46:34 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-09-12 21:46:34 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-09-12 21:46:35 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 21
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 23
# Arguments: serve
# [2022-09-12 21:46:34 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-09-12 21:46:34 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-09-12 21:46:34 +0000] [1] [INFO] Using worker: gevent
# [2022-09-12 21:46:34 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-09-12 21:46:34 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-09-12 21:46:34 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-09-12 21:46:35 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 21
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 24
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# 2022-09-12T21:46:38.916:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# Arguments: serve
# [2022-09-12 21:46:34 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-09-12 21:46:34 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-09-12 21:46:34 +0000] [1] [INFO] Using worker: gevent
# [2022-09-12 21:46:34 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-09-12 21:46:34 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-09-12 21:46:34 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-09-12 21:46:35 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 21
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 23
# Arguments: serve
# [2022-09-12 21:46:34 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-09-12 21:46:34 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-09-12 21:46:34 +0000] [1] [INFO] Using worker: gevent
# [2022-09-12 21:46:34 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-09-12 21:46:34 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-09-12 21:46:34 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-09-12 21:46:35 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 21
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-09-12:21:46:35:INFO] Model loaded successfully for worker : 24
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# [2022-09-12:21:46:40:INFO] Sniff delimiter as ','
# [2022-09-12:21:46:40:INFO] Determined delimiter of CSV input is ','
# 2022-09-12T21:46:38.916:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
xgb_transformer.output_path
# Out:
# 's3://sagemaker-us-east-1-262035634447/xgboost-2022-09-12-21-40-35-038'

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-262035634447/xgboost-2022-09-12-21-40-35-038/test.csv.out to data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.7835

# %% [markdown]
# ## Optional: Clean up

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
